# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 150)

# %%
crime = pd.read_csv(r'C:\Users\bigba\codingClass\crimedata2.csv',encoding = "ISO-8859-1")
crime.head().T
# Out:
#                                              0               1           2  \
# Êcommunityname         BerkeleyHeightstownship  Marpletownship  Tigardcity
# state                                       NJ              PA          OR
# countyCode                                  39              45           ?
# communityCode                             5320           47616           ?
# fold                                         1               1           1
# population                               11980           23123       29344
# householdsize                              3.1            2.82        2.43
# racepctblack                              1.37             0.8        0.74
# racePctWhite                             91.78           95.57       94.33
# racePctAsian                               6.5            3.44        3.43
# racePctHisp                               1.88            0.85        2.35
# agePct12t21                              12.47           11.01       11.36
# agePct12t29                              21.44            21.3       25.88
# agePct16t24                              10.93           10.48       11.01
# agePct65up                               11.33           17.18       10.28
# numbUrban                                11980           23123       29344
# pctUrban                                 100.0           100.0       100.0
# medIncome                                75122           47917       35669
# pctWWage                                 89.24           78.99        82.0
# pctWFarmSelf                              1.55            1.11        1.15
# pctWInvInc                                70.2           64.11       55.73
# pctWSocSec                               23.62            35.5       22.25
# pctWPubAsst                               1.03            2.75        2.94
# pctWRetire                               18.39           22.85       14.56
# medFamInc                                79584           55323       42112
# perCapInc                                29711           20148       16946
# whitePerCap                              30233           20191       17103
# blackPerCap                              13600           18137       16644
# indianPerCap                              5725               0       21606
# AsianPerCap                              27101           20074       15528
# OtherPerCap                               5115            5250        5954
# HispPerCap                               22838           12222        8405
# NumUnderPov                                227             885        1389
# PctPopUnderPov                            1.96            3.98        4.75
# PctLess9thGrade                           5.81            5.61         2.8
# PctNotHSGrad                               9.9           13.72        9.09
# PctBSorMore                              48.18           29.89       30.13
# PctUnemployed                              2.7            2.43        4.01
# PctEmploy                                64.55           61.96        69.8
# PctEmplManu                              14.65           12.26       15.95
# PctEmplProfServ                          28.82           29.28       21.52
# PctOccupManu                              5.49            6.39        8.79
# PctOccupMgmtProf                         50.73           37.64       32.48
# MalePctDivorce                            3.67            4.23        10.1
# MalePctNevMarr                           26.38           27.99       25.78
# FemalePctDiv                              5.22            6.45       14.76
# TotalPctDiv                               4.47            5.42       12.55
# PersPerFam                                3.22            3.11        2.95
# PctFam2Par                               91.43           86.91       78.54
# PctKids2Par                              90.17           85.33       78.85
# PctYoungKids2Par                         95.78           96.82       92.37
# PctTeen2Par                              95.81           86.46       75.72
# PctWorkMomYoungKids                      44.56           51.14       66.08
# PctWorkMom                               58.88           62.43       74.19
# NumKidsBornNeverMar                         31              43         164
# PctKidsBornNeverMar                       0.36            0.24        0.88
# NumImmig                                  1277            1920        1468
# PctImmigRecent                            8.69            5.21       16.42
# PctImmigRec5                              13.0            8.65       23.98
# PctImmigRec8                             20.99           13.33       32.08
# PctImmigRec10                            30.93            22.5       35.63
# PctRecentImmig                            0.93            0.43        0.82
# PctRecImmig5                              1.39            0.72         1.2
# PctRecImmig8                              2.24            1.11        1.61
# PctRecImmig10                              3.3            1.87        1.78
# PctSpeakEnglOnly                         85.68           87.79       93.11
# PctNotSpeakEnglWell                       1.37            1.81        1.14
# PctLargHouseFam                           4.81            4.25        2.97
# PctLargHouseOccup                         4.17            3.34        2.05
# PersPerOccupHous                          2.99             2.7        2.42
# PersPerOwnOccHous                          3.0            2.83        2.69
# PersPerRentOccHous                        2.84            1.96        2.06
# PctPersOwnOccup                          91.46           89.03       64.18
# PctPersDenseHous                          0.39            1.01        2.03
# PctHousLess3BR                           11.06            23.6       47.46
# MedNumBR                                     3               3           3
# HousVacant                                  64             240         544
# PctHousOccup                             98.37           97.15       95.68
# PctHousOwnOcc                            91.01           84.88       57.79
# PctVacantBoarded                          3.12             0.0        0.92
# PctVacMore6Mos                            37.5           18.33        7.54
# MedYrHousBuilt                            1959            1958        1976
# PctHousNoPhone                             0.0            0.31        1.55
# PctWOFullPlumb                            0.28            0.14        0.12
# OwnOccLowQuart                          215900          136300       74700
# OwnOccMedVal                            262600          164200       90400
# OwnOccHiQuart                           326900          199900      112000
# OwnOccQrange                            111000           63600       37300
# RentLowQ                                   685             467         370
# RentMedian                                1001             560         428
# RentHighQ                                 1001             672         520
# RentQrange                                 316             205         150
# MedRent                                   1001             627         484
# MedRentPctHousInc                         23.8            27.6        24.1
# MedOwnCostPctInc                          21.1            20.7        21.7
# MedOwnCostPctIncNoMtg                     14.0            12.5        11.6
# NumInShelters                               11               0          16
# NumStreet                                    0               0           0
# PctForeignBorn                           10.66             8.3         5.0
# PctBornSameState                         53.72           77.17       44.77
# PctSameHouse85                           65.29           71.27        36.6
# PctSameCity85                            78.09           90.22       61.26
# PctSameState85                           89.14           96.12       82.85
# LemasSwornFT                                 ?               ?           ?
# LemasSwFTPerPop                              ?               ?           ?
# LemasSwFTFieldOps                            ?               ?           ?
# LemasSwFTFieldPerPop                         ?               ?           ?
# LemasTotalReq                                ?               ?           ?
# LemasTotReqPerPop                            ?               ?           ?
# PolicReqPerOffic                             ?               ?           ?
# PolicPerPop                                  ?               ?           ?
# RacialMatchCommPol                           ?               ?           ?
# PctPolicWhite                                ?               ?           ?
# PctPolicBlack                                ?               ?           ?
# PctPolicHisp                                 ?               ?           ?
# PctPolicAsian                                ?               ?           ?
# PctPolicMinor                                ?               ?           ?
# OfficAssgnDrugUnits                          ?               ?           ?
# NumKindsDrugsSeiz                            ?               ?           ?
# PolicAveOTWorked                             ?               ?           ?
# LandArea                                   6.5            10.6        10.6
# PopDens                                 1845.9          2186.7      2780.9
# PctUsePubTrans                            9.63            3.84        4.37
# PolicCars                                    ?               ?           ?
# PolicOperBudg                                ?               ?           ?
# LemasPctPolicOnPatr                          ?               ?           ?
# LemasGangUnitDeploy                          ?               ?           ?
# LemasPctOfficDrugUn                        0.0             0.0         0.0
# PolicBudgPerPop                              ?               ?           ?
# murders                                      0               0           3
# murdPerPop                                 0.0             0.0         8.3
# rapes                                        0               1           6
# rapesPerPop                                  0            4.25        16.6
# robberies                                    1               5          56
# robbbPerPop                                8.2           21.26      154.95
# assaults                                     4              24          14
# assaultPerPop                            32.81          102.05       38.74
# burglaries                                  14              57         274
# burglPerPop                             114.85          242.37      758.14
# larcenies                                  138             376        1797
# larcPerPop                             1132.08         1598.78     4972.19
# autoTheft                                   16              26         136
# autoTheftPerPop                         131.26          110.55       376.3
# arsons                                       2               1          22
# arsonsPerPop                             16.41            4.25       60.87
# ViolentCrimesPerPop                      41.02          127.56      218.59
# nonViolPerPop                          1394.59         1955.95     6167.51
#
#                                       3            4
# Êcommunityname         Gloversvillecity  Bemidjicity
# state                                NY           MN
# countyCode                           35            7
# communityCode                     29443         5068
# fold                                  1            1
# population                        16656        11245
# householdsize                       2.4         2.76
# racepctblack                        1.7         0.53
# racePctWhite                      97.35        89.16
# racePctAsian                        0.5         1.17
# racePctHisp                         0.7         0.52
# agePct12t21                       12.55        24.46
# agePct12t29                        25.2        40.53
# agePct16t24                       12.19        28.69
# agePct65up                        17.57        12.65
# numbUrban                             0            0
# pctUrban                            0.0          0.0
# medIncome                         20580        17390
# pctWWage                          68.15        69.33
# pctWFarmSelf                       0.24         0.55
# pctWInvInc                        38.95        42.82
# pctWSocSec                        39.48        32.16
# pctWPubAsst                       11.71        11.21
# pctWRetire                        18.33        14.43
# medFamInc                         26501        24018
# perCapInc                         10810         8483
# whitePerCap                       10909         9009
# blackPerCap                        9984          887
# indianPerCap                       4941         4425
# AsianPerCap                        3541         3352
# OtherPerCap                        2451         3000
# HispPerCap                         4391         1328
# NumUnderPov                        2831         2855
# PctPopUnderPov                    17.23        29.99
# PctLess9thGrade                   11.05        12.15
# PctNotHSGrad                      33.68        23.06
# PctBSorMore                       10.81        25.28
# PctUnemployed                      9.86         9.08
# PctEmploy                         54.74        52.44
# PctEmplManu                       31.22         6.89
# PctEmplProfServ                   27.43        36.54
# PctOccupManu                      26.76        10.94
# PctOccupMgmtProf                  22.71         27.8
# MalePctDivorce                    10.98         7.51
# MalePctNevMarr                    28.15        50.66
# FemalePctDiv                      14.47        11.64
# TotalPctDiv                       12.91         9.73
# PersPerFam                         2.98         2.98
# PctFam2Par                        64.02        58.59
# PctKids2Par                       62.36         55.2
# PctYoungKids2Par                  65.38        66.51
# PctTeen2Par                       67.43        79.17
# PctWorkMomYoungKids               59.59        61.22
# PctWorkMom                        70.27        68.94
# NumKidsBornNeverMar                 561          402
# PctKidsBornNeverMar                3.84          4.7
# NumImmig                            339          196
# PctImmigRecent                    13.86        46.94
# PctImmigRec5                      13.86        56.12
# PctImmigRec8                      15.34        67.86
# PctImmigRec10                     15.34         69.9
# PctRecentImmig                     0.28         0.82
# PctRecImmig5                       0.28         0.98
# PctRecImmig8                       0.31         1.18
# PctRecImmig10                      0.31         1.22
# PctSpeakEnglOnly                  94.98        94.64
# PctNotSpeakEnglWell                0.56         0.39
# PctLargHouseFam                    3.93         5.23
# PctLargHouseOccup                  2.56         3.11
# PersPerOccupHous                   2.37         2.35
# PersPerOwnOccHous                  2.51         2.55
# PersPerRentOccHous                  2.2         2.12
# PctPersOwnOccup                   58.18        58.13
# PctPersDenseHous                   1.21         2.94
# PctHousLess3BR                    45.66        55.64
# MedNumBR                              3            2
# HousVacant                          669          333
# PctHousOccup                      91.19        92.45
# PctHousOwnOcc                     54.89        53.57
# PctVacantBoarded                   2.54          3.9
# PctVacMore6Mos                    57.85        42.64
# MedYrHousBuilt                     1939         1958
# PctHousNoPhone                      7.0         7.45
# PctWOFullPlumb                     0.87         0.82
# OwnOccLowQuart                    36400        30600
# OwnOccMedVal                      49600        43200
# OwnOccHiQuart                     66500        59500
# OwnOccQrange                      30100        28900
# RentLowQ                            195          202
# RentMedian                          250          283
# RentHighQ                           309          362
# RentQrange                          114          160
# MedRent                             333          332
# MedRentPctHousInc                  28.7         32.2
# MedOwnCostPctInc                   20.6         23.2
# MedOwnCostPctIncNoMtg              14.5         12.9
# NumInShelters                         0            2
# NumStreet                             0            0
# PctForeignBorn                     2.04         1.74
# PctBornSameState                  88.71        73.75
# PctSameHouse85                     56.7        42.22
# PctSameCity85                     90.17        60.34
# PctSameState85                    96.24        89.02
# LemasSwornFT                          ?            ?
# LemasSwFTPerPop                       ?            ?
# LemasSwFTFieldOps                     ?            ?
# LemasSwFTFieldPerPop                  ?            ?
# LemasTotalReq                         ?            ?
# LemasTotReqPerPop                     ?            ?
# PolicReqPerOffic                      ?            ?
# PolicPerPop                           ?            ?
# RacialMatchCommPol                    ?            ?
# PctPolicWhite                         ?            ?
# PctPolicBlack                         ?            ?
# PctPolicHisp                          ?            ?
# PctPolicAsian                         ?            ?
# PctPolicMinor                         ?            ?
# OfficAssgnDrugUnits                   ?            ?
# NumKindsDrugsSeiz                     ?            ?
# PolicAveOTWorked                      ?            ?
# LandArea                            5.2         11.5
# PopDens                          3217.7        974.2
# PctUsePubTrans                     3.31         0.38
# PolicCars                             ?            ?
# PolicOperBudg                         ?            ?
# LemasPctPolicOnPatr                   ?            ?
# LemasGangUnitDeploy                   ?            ?
# LemasPctOfficDrugUn                 0.0          0.0
# PolicBudgPerPop                       ?            ?
# murders                               0            0
# murdPerPop                          0.0          0.0
# rapes                                10            ?
# rapesPerPop                       57.86            ?
# robberies                            10            4
# robbbPerPop                       57.86        32.04
# assaults                             33           14
# assaultPerPop                    190.93       112.14
# burglaries                          225           91
# burglPerPop                     1301.78       728.93
# larcenies                           716         1060
# larcPerPop                      4142.56      8490.87
# autoTheft                            47           91
# autoTheftPerPop                  271.93       728.93
# arsons                                ?            5
# arsonsPerPop                          ?        40.05
# ViolentCrimesPerPop              306.64            ?
# nonViolPerPop                         ?      9988.79

# %%
crime.replace('?', np.nan, inplace=True)
null_counts = crime.isnull().sum().sort_values(ascending=False)
null_counts.head(50)
# Out:
# PctPolicBlack           1872
# PolicAveOTWorked        1872
# PolicOperBudg           1872
# LemasPctPolicOnPatr     1872
# LemasGangUnitDeploy     1872
# NumKindsDrugsSeiz       1872
# PolicBudgPerPop         1872
# OfficAssgnDrugUnits     1872
# PctPolicMinor           1872
# PctPolicAsian           1872
# PctPolicHisp            1872
# PctPolicWhite           1872
# RacialMatchCommPol      1872
# PolicPerPop             1872
# PolicReqPerOffic        1872
# LemasTotReqPerPop       1872
# LemasTotalReq           1872
# LemasSwFTFieldPerPop    1872
# LemasSwFTFieldOps       1872
# LemasSwFTPerPop         1872
# LemasSwornFT            1872
# PolicCars               1872
# communityCode           1224
# countyCode              1221
# ViolentCrimesPerPop      221
# rapesPerPop              208
# rapes                    208
# nonViolPerPop             97
# arsonsPerPop              91
# arsons                    91
# assaults                  13
# assaultPerPop             13
# autoTheftPerPop            3
# autoTheft                  3
# larcenies                  3
# burglPerPop                3
# burglaries                 3
# larcPerPop                 3
# robbbPerPop                1
# robberies                  1
# OtherPerCap                1
# PctWOFullPlumb             0
# OwnOccHiQuart              0
# OwnOccQrange               0
# OwnOccMedVal               0
# RentLowQ                   0
# RentMedian                 0
# RentHighQ                  0
# OwnOccLowQuart             0
# PopDens                    0
# dtype: int64

# %%
crime2 = crime.loc[:, crime.isnull().sum() <= 100]

# %%
crime2.shape
# Out:
# (2215, 120)

# %%
null_counts2 = crime2.isnull().sum().sort_values(ascending=False)
null_counts2.head()
# Out:
# nonViolPerPop    97
# arsonsPerPop     91
# arsons           91
# assaultPerPop    13
# assaults         13
# dtype: int64

# %%
crime3 = crime2.dropna()
crime3.isnull().sum().sort_values(ascending=False).head()
# Out:
# Êcommunityname    0
# state             0
# RentHighQ         0
# RentMedian        0
# RentLowQ          0
# dtype: int64

# %%
crime3.head(1).T
# Out:
#                                              0
# Êcommunityname         BerkeleyHeightstownship
# state                                       NJ
# fold                                         1
# population                               11980
# householdsize                              3.1
# racepctblack                              1.37
# racePctWhite                             91.78
# racePctAsian                               6.5
# racePctHisp                               1.88
# agePct12t21                              12.47
# agePct12t29                              21.44
# agePct16t24                              10.93
# agePct65up                               11.33
# numbUrban                                11980
# pctUrban                                 100.0
# medIncome                                75122
# pctWWage                                 89.24
# pctWFarmSelf                              1.55
# pctWInvInc                                70.2
# pctWSocSec                               23.62
# pctWPubAsst                               1.03
# pctWRetire                               18.39
# medFamInc                                79584
# perCapInc                                29711
# whitePerCap                              30233
# blackPerCap                              13600
# indianPerCap                              5725
# AsianPerCap                              27101
# OtherPerCap                               5115
# HispPerCap                               22838
# NumUnderPov                                227
# PctPopUnderPov                            1.96
# PctLess9thGrade                           5.81
# PctNotHSGrad                               9.9
# PctBSorMore                              48.18
# PctUnemployed                              2.7
# PctEmploy                                64.55
# PctEmplManu                              14.65
# PctEmplProfServ                          28.82
# PctOccupManu                              5.49
# PctOccupMgmtProf                         50.73
# MalePctDivorce                            3.67
# MalePctNevMarr                           26.38
# FemalePctDiv                              5.22
# TotalPctDiv                               4.47
# PersPerFam                                3.22
# PctFam2Par                               91.43
# PctKids2Par                              90.17
# PctYoungKids2Par                         95.78
# PctTeen2Par                              95.81
# PctWorkMomYoungKids                      44.56
# PctWorkMom                               58.88
# NumKidsBornNeverMar                         31
# PctKidsBornNeverMar                       0.36
# NumImmig                                  1277
# PctImmigRecent                            8.69
# PctImmigRec5                              13.0
# PctImmigRec8                             20.99
# PctImmigRec10                            30.93
# PctRecentImmig                            0.93
# PctRecImmig5                              1.39
# PctRecImmig8                              2.24
# PctRecImmig10                              3.3
# PctSpeakEnglOnly                         85.68
# PctNotSpeakEnglWell                       1.37
# PctLargHouseFam                           4.81
# PctLargHouseOccup                         4.17
# PersPerOccupHous                          2.99
# PersPerOwnOccHous                          3.0
# PersPerRentOccHous                        2.84
# PctPersOwnOccup                          91.46
# PctPersDenseHous                          0.39
# PctHousLess3BR                           11.06
# MedNumBR                                     3
# HousVacant                                  64
# PctHousOccup                             98.37
# PctHousOwnOcc                            91.01
# PctVacantBoarded                          3.12
# PctVacMore6Mos                            37.5
# MedYrHousBuilt                            1959
# PctHousNoPhone                             0.0
# PctWOFullPlumb                            0.28
# OwnOccLowQuart                          215900
# OwnOccMedVal                            262600
# OwnOccHiQuart                           326900
# OwnOccQrange                            111000
# RentLowQ                                   685
# RentMedian                                1001
# RentHighQ                                 1001
# RentQrange                                 316
# MedRent                                   1001
# MedRentPctHousInc                         23.8
# MedOwnCostPctInc                          21.1
# MedOwnCostPctIncNoMtg                     14.0
# NumInShelters                               11
# NumStreet                                    0
# PctForeignBorn                           10.66
# PctBornSameState                         53.72
# PctSameHouse85                           65.29
# PctSameCity85                            78.09
# PctSameState85                           89.14
# LandArea                                   6.5
# PopDens                                 1845.9
# PctUsePubTrans                            9.63
# LemasPctOfficDrugUn                        0.0
# murders                                      0
# murdPerPop                                 0.0
# robberies                                    1
# robbbPerPop                                8.2
# assaults                                     4
# assaultPerPop                            32.81
# burglaries                                  14
# burglPerPop                             114.85
# larcenies                                  138
# larcPerPop                             1132.08
# autoTheft                                   16
# autoTheftPerPop                         131.26
# arsons                                       2
# arsonsPerPop                             16.41
# nonViolPerPop                          1394.59

# %%
places = crime3.drop(columns = ['state', 'Êcommunityname', 'fold', 'PctImmigRecent', 'PctImmigRec5', 'PctImmigRec8',
                              'PctImmigRec10', 'PctRecentImmig', 'PctImmigRec5', 'PctImmigRec8', 'PctImmigRec10', 
                             'PctSpeakEnglOnly', 'PctNotSpeakEnglWell', 'PctForeignBorn', 'PctBornSameState', 'LandArea',
                             'PctUsePubTrans', 'LemasPctOfficDrugUn', 'murders', 'murdPerPop', 'robberies', 'robbbPerPop',
                             'assaults', 'assaultPerPop', 'larcenies', 'larcPerPop', 'autoTheft', 'autoTheft', 'autoTheftPerPop',
                             'arsons', 'arsonsPerPop', 'nonViolPerPop', 'population', 'racepctblack', 'racePctWhite',
                             'racePctAsian', 'racePctHisp', 'agePct12t21', 'agePct12t29', 'agePct16t24', 'agePct65up',
                             'numbUrban', 'pctUrban', 'whitePerCap', 'blackPerCap', 'indianPerCap', 'AsianPerCap', 'OtherPerCap',
                             'HispPerCap', 'pctWSocSec', 'pctWFarmSelf', 'pctWRetire', 'MalePctDivorce', 'MalePctNevMarr',
                             'FemalePctDiv', 'TotalPctDiv', 'PctRecImmig5', 'PctRecImmig8', 'PctRecImmig10', 'NumImmig',
                            'PersPerFam', 'PctFam2Par', 'PctKids2Par', 'PctYoungKids2Par', 'PctTeen2Par', 'PctWorkMomYoungKids',
                             'PctWorkMom', 'PersPerOccupHous', 'PersPerOwnOccHous', 'PersPerRentOccHous', 'PctPersOwnOccup',
                             'PctPersDenseHous', 'PctHousLess3BR', 'MedNumBR', 'HousVacant', 'PctHousOccup', 'PctHousOwnOcc',
                             'PctVacantBoarded', 'PctVacMore6Mos', 'MedYrHousBuilt', 'PctLargHouseFam', 'PctLargHouseOccup',
                             'PctHousNoPhone', 'PctWOFullPlumb', 'OwnOccLowQuart', 'OwnOccMedVal', 'OwnOccHiQuart' ,'OwnOccQrange',
                             'RentLowQ', 'RentMedian', 'RentHighQ', 'RentQrange', 'MedRent', 'MedRentPctHousInc', 'MedOwnCostPctInc',
                             'MedOwnCostPctIncNoMtg', 'PopDens', 'NumKidsBornNeverMar',
                             'PctKidsBornNeverMar', 'NumStreet', 'PctOccupManu', 'PctOccupMgmtProf'])

# %%
trim = places.drop(columns = ['PctSameHouse85', 'PctSameCity85', 'PctSameState85', ])

# %%
trim.head(1).T
# Out:
#                       0
# householdsize       3.1
# medIncome         75122
# pctWWage          89.24
# pctWInvInc         70.2
# pctWPubAsst        1.03
# medFamInc         79584
# perCapInc         29711
# NumUnderPov         227
# PctPopUnderPov     1.96
# PctLess9thGrade    5.81
# PctNotHSGrad        9.9
# PctBSorMore       48.18
# PctUnemployed       2.7
# PctEmploy         64.55
# PctEmplManu       14.65
# PctEmplProfServ   28.82
# NumInShelters        11
# burglaries           14
# burglPerPop      114.85

# %%
trim.shape
# Out:
# (2107, 19)

# %%
trim.head()
# Out:
#    householdsize  medIncome  pctWWage  pctWInvInc  pctWPubAsst  medFamInc  \
# 0           3.10      75122     89.24       70.20         1.03      79584
# 1           2.82      47917     78.99       64.11         2.75      55323
# 2           2.43      35669     82.00       55.73         2.94      42112
# 4           2.76      17390     69.33       42.82        11.21      24018
# 5           2.45      21577     75.78       41.15         7.12      27705
#
#    perCapInc  NumUnderPov  PctPopUnderPov  PctLess9thGrade  PctNotHSGrad  \
# 0      29711          227            1.96             5.81          9.90
# 1      20148          885            3.98             5.61         13.72
# 2      16946         1389            4.75             2.80          9.09
# 4       8483         2855           29.99            12.15         23.06
# 5      11878        23223           17.78             8.76         23.03
#
#    PctBSorMore  PctUnemployed  PctEmploy  PctEmplManu  PctEmplProfServ  \
# 0        48.18           2.70      64.55        14.65            28.82
# 1        29.89           2.43      61.96        12.26            29.28
# 2        30.13           4.01      69.80        15.95            21.52
# 4        25.28           9.08      52.44         6.89            36.54
# 5        20.66           5.72      59.02        14.31            26.83
#
#    NumInShelters burglaries burglPerPop
# 0             11         14      114.85
# 1              0         57      242.37
# 2             16        274      758.14
# 4              2         91      728.93
# 5            327       2094     1386.46

# %%
trim.columns = [
    'HouseholdSize', 'AvgIncome', 'PerWithIncome', 'PerInvested', 'PerPubAssist', 
    'MedIncome', 'PerCap', 'NumInPov', 'PerInPov', 'PerLess9thGrade', 
    'PctNoHSGrad', 'PctBSorMore', 'PctUnemployed', 'PctEmployed', 'PctManuel', 
    'PctMgmt', 'NumInShelter', 'Burglaries', 'BurgPerPop'
]

# %%
trim.head()
# Out:
#    HouseholdSize  AvgIncome  PerWithIncome  PerInvested  PerPubAssist  \
# 0           3.10      75122          89.24        70.20          1.03
# 1           2.82      47917          78.99        64.11          2.75
# 2           2.43      35669          82.00        55.73          2.94
# 4           2.76      17390          69.33        42.82         11.21
# 5           2.45      21577          75.78        41.15          7.12
#
#    MedIncome  PerCap  NumInPov  PerInPov  PerLess9thGrade  PctNoHSGrad  \
# 0      79584   29711       227      1.96             5.81         9.90
# 1      55323   20148       885      3.98             5.61        13.72
# 2      42112   16946      1389      4.75             2.80         9.09
# 4      24018    8483      2855     29.99            12.15        23.06
# 5      27705   11878     23223     17.78             8.76        23.03
#
#    PctBSorMore  PctUnemployed  PctEmployed  PctManuel  PctMgmt  NumInShelter  \
# 0        48.18           2.70        64.55      14.65    28.82            11
# 1        29.89           2.43        61.96      12.26    29.28             0
# 2        30.13           4.01        69.80      15.95    21.52            16
# 4        25.28           9.08        52.44       6.89    36.54             2
# 5        20.66           5.72        59.02      14.31    26.83           327
#
#   Burglaries BurgPerPop
# 0         14     114.85
# 1         57     242.37
# 2        274     758.14
# 4         91     728.93
# 5       2094    1386.46

# %%
import matplotlib.pyplot as plt

for column in trim.columns:
    plt.figure()
    trim[column].hist(bins=10)
    plt.title(f'Histogram of {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.show()

# %%
# Create columns which show the average and median income for individuals, as opposed to households
trim['AvgIncPerPerson'] = (trim['AvgIncome'] / trim['HouseholdSize']).round(1)
trim['MedIncPerPerson'] = (trim['MedIncome'] / trim['HouseholdSize']).round(1)

# %%
from sklearn.model_selection import train_test_split

# Define the features and target variable for the first test, using AvgIncome
avgFeatures = ['HouseholdSize', 'AvgIncome', 'PerWithIncome', 'PerInvested', 'PerPubAssist', 
            'PerInPov', 'PerLess9thGrade', 'PctNoHSGrad', 'PctBSorMore', 'PctUnemployed', 
            'PctEmployed', 'PctManuel', 'PctMgmt', 'NumInShelter']
target = 'BurgPerPop'

# Split the data into training and testing sets
X = trim[avgFeatures]
y = trim[target]
X_train, X_test, y_train, y_test = train_test_split(X,y)

# %%
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor

# Initialize the models
rf_model = RandomForestRegressor(random_state=42)
gbm_model = GradientBoostingRegressor(random_state=42)

# Train the models
rf_model.fit(X_train, y_train)
gbm_model.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor(random_state=42)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

rf_predictions = rf_model.predict(X_test)
gbm_predictions = gbm_model.predict(X_test)

# Calculate evaluation metrics
rf_mae = mean_absolute_error(y_test, rf_predictions)
rf_mse = mean_squared_error(y_test, rf_predictions)
rf_rmse = np.sqrt(rf_mse)

gbm_mae = mean_absolute_error(y_test, gbm_predictions)
gbm_mse = mean_squared_error(y_test, gbm_predictions)
gbm_rmse = np.sqrt(gbm_mse)

# Print the evaluation metrics
print("Random Forest Regression Metrics using Average Income:")
print("MAE:", rf_mae)
print("MSE:", rf_mse)
print("RMSE:", rf_rmse)
print()
print("Gradient Boosting Regression Metrics using Average Income:")
print("MAE:", gbm_mae)
print("MSE:", gbm_mse)
print("RMSE:", gbm_rmse)
# Out:
# Random Forest Regression Metrics using Average Income:
# MAE: 362.1693388994308
# MSE: 326147.40495571966
# RMSE: 571.0931666162007
#
# Gradient Boosting Regression Metrics using Average Income:
# MAE: 358.4926608125953
# MSE: 304585.39027791796
# RMSE: 551.8925532002746

# %%
# Define the features and target variable for the first test, using MedIncome
medFeatures = ['HouseholdSize', 'MedIncome', 'PerWithIncome', 'PerInvested', 'PerPubAssist', 
            'PerInPov', 'PerLess9thGrade', 'PctNoHSGrad', 'PctBSorMore', 'PctUnemployed', 
            'PctEmployed', 'PctManuel', 'PctMgmt', 'NumInShelter']
target = 'BurgPerPop'

# Split the data into training and testing sets
X = trim[medFeatures]
y = trim[target]
X_train, X_test, y_train, y_test = train_test_split(X,y)

# %%
# Initialize the models
rf_model = RandomForestRegressor(random_state=42)
gbm_model = GradientBoostingRegressor(random_state=42)

# Train the models
rf_model.fit(X_train, y_train)
gbm_model.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor(random_state=42)

# %%
rf_predictions = rf_model.predict(X_test)
gbm_predictions = gbm_model.predict(X_test)

# Calculate evaluation metrics
rf_mae = mean_absolute_error(y_test, rf_predictions)
rf_mse = mean_squared_error(y_test, rf_predictions)
rf_rmse = np.sqrt(rf_mse)

gbm_mae = mean_absolute_error(y_test, gbm_predictions)
gbm_mse = mean_squared_error(y_test, gbm_predictions)
gbm_rmse = np.sqrt(gbm_mse)

# Print the evaluation metrics
print("Random Forest Regression Metrics using Median Income:")
print("MAE:", rf_mae)
print("MSE:", rf_mse)
print("RMSE:", rf_rmse)
print()
print("Gradient Boosting Regression Metrics using Median Income:")
print("MAE:", gbm_mae)
print("MSE:", gbm_mse)
print("RMSE:", gbm_rmse)
# Out:
# Random Forest Regression Metrics using Median Income:
# MAE: 391.79904838709683
# MSE: 504994.560634817
# RMSE: 710.6296930433016
#
# Gradient Boosting Regression Metrics using Median Income:
# MAE: 382.8562905938038
# MSE: 497518.05517210206
# RMSE: 705.3495978393282

# %%
trim['BurgPerPop'] = trim['BurgPerPop'].astype(float)

threshold = trim['BurgPerPop'].quantile(0.75)
trim['BurgClass'] = ['High Burglaries' if x >= threshold else 'Low Burglaries' for x in trim['BurgPerPop']]

# %%
# Split the data into training and testing sets
X = trim[avgFeatures]
y = trim['BurgClass']
X_train, X_test, y_train, y_test = train_test_split(X,y)

# %%
from sklearn import tree
from sklearn import metrics

def run_model(d=3, cw='balanced', c='gini', s='random', msl=1):
    clf = tree.DecisionTreeClassifier(max_depth=d,
                                      class_weight=cw,
                                      criterion=c,
                                      splitter=s,
                                      min_samples_leaf=msl)

    clf2 = clf.fit(X_train, y_train)

    plt.figure(figsize=(15,15))
    tree.plot_tree(clf2,
               feature_names=avgFeatures,
               class_names=['No','Yes'],
               filled=True, precision=2,
               node_ids=True, fontsize=10,
               label='root', proportion=True,
               impurity=False)

    y_pred = clf2.predict (X_test)

    print(metrics.classification_report (y_test, y_pred))
    
run_model()
# Out:
#                  precision    recall  f1-score   support
#
# High Burglaries       0.55      0.79      0.65       139
#  Low Burglaries       0.91      0.77      0.83       388
#
#        accuracy                           0.77       527
#       macro avg       0.73      0.78      0.74       527
#    weighted avg       0.82      0.77      0.78       527

# %%
# Split the data into training and testing sets
X = trim[medFeatures]
y = trim['BurgClass']
X_train, X_test, y_train, y_test = train_test_split(X,y)

# %%
def run_model(d=3, cw='balanced', c='gini', s='random', msl=1):
    clf = tree.DecisionTreeClassifier(max_depth=d,
                                      class_weight=cw,
                                      criterion=c,
                                      splitter=s,
                                      min_samples_leaf=msl)

    clf2 = clf.fit(X_train, y_train)

    plt.figure(figsize=(15,15))
    tree.plot_tree(clf2,
               feature_names=avgFeatures,
               class_names=['No','Yes'],
               filled=True, precision=2,
               node_ids=True, fontsize=10,
               label='root', proportion=True,
               impurity=False)

    y_pred = clf2.predict (X_test)

    print(metrics.classification_report (y_test, y_pred))
    
run_model()
# Out:
#                  precision    recall  f1-score   support
#
# High Burglaries       0.45      0.75      0.56       130
#  Low Burglaries       0.89      0.70      0.79       397
#
#        accuracy                           0.71       527
#       macro avg       0.67      0.72      0.67       527
#    weighted avg       0.78      0.71      0.73       527

# %%
trim.head(1).T
# Out:
#                               0
# HouseholdSize               3.1
# AvgIncome                 75122
# PerWithIncome             89.24
# PerInvested                70.2
# PerPubAssist               1.03
# MedIncome                 79584
# PerCap                    29711
# NumInPov                    227
# PerInPov                   1.96
# PerLess9thGrade            5.81
# PctNoHSGrad                 9.9
# PctBSorMore               48.18
# PctUnemployed               2.7
# PctEmployed               64.55
# PctManuel                 14.65
# PctMgmt                   28.82
# NumInShelter                 11
# Burglaries                   14
# BurgPerPop               114.85
# AvgIncPerPerson         24232.9
# MedIncPerPerson         25672.3
# BurgClass        Low Burglaries

# %%
trim = trim.drop(columns=['BurgClass'])

# %%
trim[['Burglaries', 'BurgPerPop']] = trim[['Burglaries', 'BurgPerPop']].astype(float)
trim.dtypes
# Out:
# HouseholdSize      float64
# AvgIncome            int64
# PerWithIncome      float64
# PerInvested        float64
# PerPubAssist       float64
# MedIncome            int64
# PerCap               int64
# NumInPov             int64
# PerInPov           float64
# PerLess9thGrade    float64
# PctNoHSGrad        float64
# PctBSorMore        float64
# PctUnemployed      float64
# PctEmployed        float64
# PctManuel          float64
# PctMgmt            float64
# NumInShelter         int64
# Burglaries         float64
# BurgPerPop         float64
# AvgIncPerPerson    float64
# MedIncPerPerson    float64
# dtype: object

# %%
def categorize_numerical_columns(df, features):
    # Create a copy of the DataFrame to avoid modifying the original
    df_categorized = pd.DataFrame()
    
    # Loop through each specified numerical column in the features list
    for column in features:
        # Calculate the quartiles
        q1 = df[column].quantile(0.25)
        q2 = df[column].quantile(0.75)
        
        # Create a categorical variable based on quartiles
        df_categorized[column] = pd.cut(
            df[column],
            bins=[-float('inf'), q1, q2, float('inf')],
            labels=['Low', 'Medium', 'High']
        )
    
    return df_categorized

trim_categorized = categorize_numerical_columns(trim, avgFeatures)

# %%
# Ensure BurgPerPop is float type
trim['BurgPerPop'] = trim['BurgPerPop'].astype(float)

# Create a new column 'BurgClass' based on the 75th percentile threshold
threshold = trim['BurgPerPop'].quantile(0.75)
trim['BurgClass'] = ['High Burglaries' if x >= threshold else 'Low Burglaries' for x in trim['BurgPerPop']]

# Assume the categorize_numerical_columns function has already been defined and run
trim_categorized = categorize_numerical_columns(trim, avgFeatures)

# Add the 'BurgClass' column back to the categorized DataFrame
trim_categorized['BurgClass'] = trim['BurgClass'].reset_index(drop=True)

# Define the features and target variable for the first test
# We want to use the categorized columns as features
avgFeatures = trim_categorized.columns.drop('BurgClass')  # Only keep the features, drop 'BurgClass'
target = 'BurgClass'

# Split the data into training and testing sets
X = trim_categorized[avgFeatures]
y = trim_categorized[target]
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
trim_categorized.head()
# Out:
#   HouseholdSize AvgIncome PerWithIncome PerInvested PerPubAssist PerInPov  \
# 0          High      High          High        High          Low      Low
# 1        Medium      High        Medium        High          Low      Low
# 2           Low    Medium        Medium        High          Low   Medium
# 4        Medium       Low           Low      Medium         High     High
# 5           Low       Low        Medium      Medium       Medium     High
#
#   PerLess9thGrade PctNoHSGrad PctBSorMore PctUnemployed PctEmployed PctManuel  \
# 0          Medium         Low        High           Low      Medium    Medium
# 1          Medium         Low        High           Low      Medium    Medium
# 2             Low         Low        High           Low        High    Medium
# 4            High      Medium      Medium          High         Low       Low
# 5          Medium      Medium      Medium        Medium      Medium    Medium
#
#   PctMgmt NumInShelter        BurgClass
# 0    High       Medium   Low Burglaries
# 1    High          Low   Low Burglaries
# 2  Medium       Medium   Low Burglaries
# 4    High       Medium  High Burglaries
# 5  Medium         High   Low Burglaries

# %%
trim_dummies = pd.get_dummies(trim_categorized)

# %%
avgFeatures = trim_dummies.drop(columns=['BurgClass_High Burglaries','BurgClass_Low Burglaries'])

# %%
# Split the data into training and testing sets
X = avgFeatures
y = trim_dummies['BurgClass_High Burglaries']
X_train, X_test, y_train, y_test = train_test_split(X,y)

# %%
# Initialize the models
rf_model = RandomForestRegressor(random_state=42)
gbm_model = GradientBoostingRegressor(random_state=42)

# Train the models
rf_model.fit(X_train, y_train)
gbm_model.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor(random_state=42)

# %%
rf_predictions = rf_model.predict(X_test)
gbm_predictions = gbm_model.predict(X_test)

# Calculate evaluation metrics
rf_mae = mean_absolute_error(y_test, rf_predictions)
rf_mse = mean_squared_error(y_test, rf_predictions)
rf_rmse = np.sqrt(rf_mse)

gbm_mae = mean_absolute_error(y_test, gbm_predictions)
gbm_mse = mean_squared_error(y_test, gbm_predictions)
gbm_rmse = np.sqrt(gbm_mse)

# Print the evaluation metrics
print("Random Forest Regression Metrics using Average Income:")
print("MAE:", rf_mae)
print("MSE:", rf_mse)
print("RMSE:", rf_rmse)
print()
print("Gradient Boosting Regression Metrics using Average Income:")
print("MAE:", gbm_mae)
print("MSE:", gbm_mse)
print("RMSE:", gbm_rmse)
# Out:
# Random Forest Regression Metrics using Average Income:
# MAE: 0.381889254971538
# MSE: 0.22283495767734862
# RMSE: 0.4720539775040018
#
# Gradient Boosting Regression Metrics using Average Income:
# MAE: 0.3731011307152351
# MSE: 0.20170257625794033
# RMSE: 0.4491130996285238

# %%
def run_model(d=3, cw='balanced', c='gini', s='random', msl=1):
    # Check if avgFeatures contains the correct columns for one-hot encoded features
    try:
        clf = tree.DecisionTreeClassifier(max_depth=d,
                                           class_weight=cw,
                                           criterion=c,
                                           splitter=s,
                                           min_samples_leaf=msl)

        clf2 = clf.fit(X_train, y_train)

        plt.figure(figsize=(15, 15))
        tree.plot_tree(clf2,
                       feature_names=X_train.columns.tolist(),
                       class_names=['Low Burglaries', 'High Burglaries'],
                       filled=True, precision=2,
                       node_ids=True, fontsize=10,
                       label='root', proportion=True,
                       impurity=False)

        y_pred = clf2.predict(X_test)

        print(metrics.classification_report(y_test, y_pred))

    except Exception as e:
        print(f"An error occurred: {e}")

run_model()
# Out:
#               precision    recall  f1-score   support
#
#        False       0.75      0.63      0.68       394
#         True       0.25      0.37      0.30       133
#
#     accuracy                           0.56       527
#    macro avg       0.50      0.50      0.49       527
# weighted avg       0.62      0.56      0.58       527

# %%
trim_categorized = categorize_numerical_columns(trim, medFeatures)

# Assume the categorize_numerical_columns function has already been defined and run
trim_categorized = categorize_numerical_columns(trim, medFeatures)

# Add the 'BurgClass' column back to the categorized DataFrame
trim_categorized['BurgClass'] = trim['BurgClass'].reset_index(drop=True)

# Define the features and target variable for the first test
# We want to use the categorized columns as features
medFeatures = trim_categorized.columns.drop('BurgClass')  # Only keep the features, drop 'BurgClass'
target = 'BurgClass'

# Split the data into training and testing sets
X = trim_categorized[medFeatures]
y = trim_categorized[target]
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
trim_dummies = pd.get_dummies(trim_categorized)

# %%
medFeatures = trim_dummies.drop(columns=['BurgClass_High Burglaries','BurgClass_Low Burglaries'])

# %%
# Split the data into training and testing sets
X = medFeatures
y = trim_dummies['BurgClass_High Burglaries']
X_train, X_test, y_train, y_test = train_test_split(X,y)

# %%
# Initialize the models
rf_model = RandomForestRegressor(random_state=42)
gbm_model = GradientBoostingRegressor(random_state=42)

# Train the models
rf_model.fit(X_train, y_train)
gbm_model.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor(random_state=42)

# %%
rf_predictions = rf_model.predict(X_test)
gbm_predictions = gbm_model.predict(X_test)

# Calculate evaluation metrics
rf_mae = mean_absolute_error(y_test, rf_predictions)
rf_mse = mean_squared_error(y_test, rf_predictions)
rf_rmse = np.sqrt(rf_mse)

gbm_mae = mean_absolute_error(y_test, gbm_predictions)
gbm_mse = mean_squared_error(y_test, gbm_predictions)
gbm_rmse = np.sqrt(gbm_mse)

# Print the evaluation metrics
print("Random Forest Regression Metrics using Median Income:")
print("MAE:", rf_mae)
print("MSE:", rf_mse)
print("RMSE:", rf_rmse)
print()
print("Gradient Boosting Regression Metrics using Median Income:")
print("MAE:", gbm_mae)
print("MSE:", gbm_mse)
print("RMSE:", gbm_rmse)
# Out:
# Random Forest Regression Metrics using Median Income:
# MAE: 0.3704185536299751
# MSE: 0.21036669850920275
# RMSE: 0.45865749586069426
#
# Gradient Boosting Regression Metrics using Median Income:
# MAE: 0.3519454340694469
# MSE: 0.17383271488489682
# RMSE: 0.4169325063902991

# %%
def run_model(d=3, cw='balanced', c='gini', s='random', msl=1):
    try:
        clf = tree.DecisionTreeClassifier(max_depth=d,
                                           class_weight=cw,
                                           criterion=c,
                                           splitter=s,
                                           min_samples_leaf=msl)

        clf2 = clf.fit(X_train, y_train)

        plt.figure(figsize=(15, 15))
        tree.plot_tree(clf2,
                       feature_names=X_train.columns.tolist(),
                       class_names=['Low Burglaries', 'High Burglaries'],
                       filled=True, precision=2,
                       node_ids=True, fontsize=10,
                       label='root', proportion=True,
                       impurity=False)

        y_pred = clf2.predict(X_test)

        print(metrics.classification_report(y_test, y_pred))

    except Exception as e:
        print(f"An error occurred: {e}")

run_model()
# Out:
#               precision    recall  f1-score   support
#
#        False       0.86      0.16      0.26       416
#         True       0.22      0.90      0.36       111
#
#     accuracy                           0.31       527
#    macro avg       0.54      0.53      0.31       527
# weighted avg       0.72      0.31      0.28       527

# %%
places.columns
# Out:
# Index(['householdsize', 'medIncome', 'pctWWage', 'pctWInvInc', 'pctWPubAsst',
#        'medFamInc', 'perCapInc', 'NumUnderPov', 'PctPopUnderPov',
#        'PctLess9thGrade', 'PctNotHSGrad', 'PctBSorMore', 'PctUnemployed',
#        'PctEmploy', 'PctEmplManu', 'PctEmplProfServ', 'NumInShelters',
#        'PctSameHouse85', 'PctSameCity85', 'PctSameState85', 'burglaries',
#        'burglPerPop'],
#       dtype='object')

# %%
corrtest = places.drop(columns=['householdsize', 'medIncome', 'pctWWage', 'pctWInvInc', 'pctWPubAsst',
       'medFamInc', 'perCapInc', 'NumUnderPov', 'PctPopUnderPov',
       'PctLess9thGrade', 'PctNotHSGrad', 'PctBSorMore', 'PctUnemployed',
       'PctEmploy', 'PctEmplManu', 'PctEmplProfServ', 'NumInShelters', 'burglaries'])

# %%
corrtest.corr()
# Out:
#                 PctSameHouse85  PctSameCity85  PctSameState85  burglPerPop
# PctSameHouse85        1.000000       0.804595        0.656415    -0.204957
# PctSameCity85         0.804595       1.000000        0.725802     0.010459
# PctSameState85        0.656415       0.725802        1.000000    -0.060021
# burglPerPop          -0.204957       0.010459       -0.060021     1.000000

# %%
## Places where people don't move have more burglaries

# %%
places.columns = [
    'HouseholdSize', 'AvgIncome', 'PerWithIncome', 'PerInvested', 'PerPubAssist', 
    'MedIncome', 'PerCap', 'NumInPov', 'PerInPov', 'PerLess9thGrade', 
    'PctNoHSGrad', 'PctBSorMore', 'PctUnemployed', 'PctEmployed', 'PctManuel', 
    'PctMgmt', 'NumInShelter', 'PctSameHouse85', 'PctSameCity85', 'PctSameState85',
    'Burglaries', 'BurgPerPop'
]

# %%
places[['Burglaries', 'BurgPerPop']] = places[['Burglaries', 'BurgPerPop']].astype(float)

# %%
# Define the features and target variable for the first test, using MedIncome
medFeatures = ['HouseholdSize', 'MedIncome', 'PerWithIncome', 'PerInvested', 'PerPubAssist', 
            'PerInPov', 'PerLess9thGrade', 'PctNoHSGrad', 'PctBSorMore', 'PctUnemployed', 
            'PctEmployed', 'PctManuel', 'PctMgmt', 'NumInShelter', 'PctSameHouse85', 
               'PctSameCity85', 'PctSameState85']

# %%
def categorize_numerical_columns(df, features):
    # Create a copy of the DataFrame to avoid modifying the original
    df_categorized = pd.DataFrame()
    
    # Loop through each specified numerical column in the features list
    for column in features:
        # Calculate the quartiles
        q1 = df[column].quantile(0.25)
        q2 = df[column].quantile(0.75)
        
        # Create a categorical variable based on quartiles
        df_categorized[column] = pd.cut(
            df[column],
            bins=[-float('inf'), q1, q2, float('inf')],
            labels=['Low', 'Medium', 'High']
        )
    
    return df_categorized

places_categorized = categorize_numerical_columns(places, medFeatures)

# %%
# Ensure BurgPerPop is float type
places['BurgPerPop'] = places['BurgPerPop'].astype(float)

# Create a new column 'BurgClass' based on the 75th percentile threshold
threshold = places['BurgPerPop'].quantile(0.75)
places['BurgClass'] = ['High Burglaries' if x >= threshold else 'Low Burglaries' for x in places['BurgPerPop']]

# Assume the categorize_numerical_columns function has already been defined and run
places_categorized = categorize_numerical_columns(places, medFeatures)

# Add the 'BurgClass' column back to the categorized DataFrame
places_categorized['BurgClass'] = places['BurgClass'].reset_index(drop=True)

# Define the features and target variable for the first test
# We want to use the categorized columns as features
medFeatures = places_categorized.columns.drop('BurgClass')  # Only keep the features, drop 'BurgClass'
target = 'BurgClass'

# Split the data into training and testing sets
X = places_categorized[medFeatures]
y = places_categorized[target]
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
places_dummies = pd.get_dummies(places_categorized)

# %%
medFeatures = places_dummies.drop(columns=['BurgClass_High Burglaries','BurgClass_Low Burglaries'])

# %%
# Split the data into training and testing sets
X = medFeatures
y = places_dummies['BurgClass_High Burglaries']
X_train, X_test, y_train, y_test = train_test_split(X,y)

# %%
# Initialize the models
rf_model = RandomForestRegressor(random_state=42)
gbm_model = GradientBoostingRegressor(random_state=42)

# Train the models
rf_model.fit(X_train, y_train)
gbm_model.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor(random_state=42)

# %%
rf_predictions = rf_model.predict(X_test)
gbm_predictions = gbm_model.predict(X_test)

# Calculate evaluation metrics
rf_mae = mean_absolute_error(y_test, rf_predictions)
rf_mse = mean_squared_error(y_test, rf_predictions)
rf_rmse = np.sqrt(rf_mse)

gbm_mae = mean_absolute_error(y_test, gbm_predictions)
gbm_mse = mean_squared_error(y_test, gbm_predictions)
gbm_rmse = np.sqrt(gbm_mse)

# Print the evaluation metrics
print("Random Forest Regression Metrics using Median Income:")
print("MAE:", rf_mae)
print("MSE:", rf_mse)
print("RMSE:", rf_rmse)
print()
print("Gradient Boosting Regression Metrics using Median Income:")
print("MAE:", gbm_mae)
print("MSE:", gbm_mse)
print("RMSE:", gbm_rmse)
# Out:
# Random Forest Regression Metrics using Median Income:
# MAE: 0.3813770260942937
# MSE: 0.21422654974116104
# RMSE: 0.4628461404626391
#
# Gradient Boosting Regression Metrics using Median Income:
# MAE: 0.36961356535844636
# MSE: 0.20132214991173705
# RMSE: 0.4486893690647652
